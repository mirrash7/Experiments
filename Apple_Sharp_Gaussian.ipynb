# %% [markdown]
# <a href="https://colab.research.google.com/github/mirrash7/Experiments/blob/main/Apple_Sharp_Gaussian.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from google.colab import userdata

os.environ["HF_TOKEN"] = userdata.get("HF_TOKEN")
os.environ["ROBOFLOW_API_KEY"] = userdata.get("ROBOFLOW_API_KEY")

# %%
# !nvidia-smi
# Out:
# Thu Dec 25 17:30:57 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   48C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !git clone https://github.com/apple/ml-sharp.git
# %cd ml-sharp
# Out:
# Cloning into 'ml-sharp'...
# remote: Enumerating objects: 433, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 433 (delta 5), reused 3 (delta 3), pack-reused 412 (from 1)
# Receiving objects: 100% (433/433), 185.05 MiB | 15.90 MiB/s, done.
# Resolving deltas: 100% (26/26), done.
# /content/ml-sharp

# %%
# !pip install -r requirements.txt
# !pip install .
# Out:
# Obtaining file:///content/ml-sharp (from -r requirements.txt (line 3))
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Ignoring colorama: markers 'sys_platform == "win32"' don't match your environment
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.2/113.2 kB 12.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 7.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 5.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 6.0 MB/s eta 0:00:00
# ...
#   Using cached setuptools-80.9.0-py3-none-any.whl.metadata (6.6 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 kB 7.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.2/161.2 kB 18.2 MB/s eta 0:00:00
# ...

# %%
# !wget https://ml-site.cdn-apple.com/models/sharp/sharp_2572gikvuh.pt
# Out:
# --2025-12-25 17:35:30--  https://ml-site.cdn-apple.com/models/sharp/sharp_2572gikvuh.pt
# Resolving ml-site.cdn-apple.com (ml-site.cdn-apple.com)... 17.253.61.141, 17.253.61.138, 2403:300:a26:f000::136, ...
# Connecting to ml-site.cdn-apple.com (ml-site.cdn-apple.com)|17.253.61.141|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2809738232 (2.6G) [binary/octet-stream]
# Saving to: ‘sharp_2572gikvuh.pt’
#
# sharp_2572gikvuh.pt  25%[====>               ] 674.13M  26.1MB/s    in 26s
#
# 2025-12-25 17:35:57 (25.6 MB/s) - Read error at byte 706874616/2809738232 (Connection reset by peer). Retrying.
#
# --2025-12-25 17:35:58--  (try: 2)  https://ml-site.cdn-apple.com/models/sharp/sharp_2572gikvuh.pt
# Connecting to ml-site.cdn-apple.com (ml-site.cdn-apple.com)|17.253.61.141|:443... connected.
# HTTP request sent, awaiting response... 206 Partial Content
# Length: 2809738232 (2.6G), 2102863616 (2.0G) remaining [binary/octet-stream]
# ...

# %%
# Create an output folder
# !mkdir -p output

# Run the prediction
# Replace 'demo_images/example.jpg' with your specific image path
# !sharp predict -i BBALL.mp4 -o output/ -c sharp_2572gikvuh.pt --render
# Out:
# 2025-12-25 18:07:30,126 | INFO | No valid images found. Input was BBALL.mp4.

# %%
from IPython.display import Video
import os

# Find the mp4 file in the output folder
video_path = [os.path.join('output', f) for f in os.listdir('output') if f.endswith('.mp4')][0]
Video(video_path, embed=True, width=600)
# Out:
# <video controls  width="600" >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
